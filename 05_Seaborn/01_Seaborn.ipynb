# %% [markdown]
# statistical plotting library
# built on top of matplotlib

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
#df = sns.load_dataset('tips')
df = pd.read_csv(r"C:\Users\shrey\Desktop\DAPP_Aug2023\DATA\tips.csv")
df
# Out:
#      total_bill   tip     sex smoker   day    time  size  price_per_person  \
# 0         16.99  1.01  Female     No   Sun  Dinner     2              8.49
# 1         10.34  1.66    Male     No   Sun  Dinner     3              3.45
# 2         21.01  3.50    Male     No   Sun  Dinner     3              7.00
# 3         23.68  3.31    Male     No   Sun  Dinner     2             11.84
# 4         24.59  3.61  Female     No   Sun  Dinner     4              6.15
# ..          ...   ...     ...    ...   ...     ...   ...               ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3              9.68
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2             13.59
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2             11.34
# 242       17.82  1.75    Male     No   Sat  Dinner     2              8.91
# 243       18.78  3.00  Female     No  Thur  Dinner     2              9.39
#
#              Payer Name         CC Number Payment ID
# ...

# %% [markdown]
# # distplot
#
# shows distribution of a univariate(one variable) set of observations.

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
sns.distplot(df['total_bill'])
# Out:
# <Axes: xlabel='total_bill', ylabel='Density'>

# %% [markdown]
# kde: kernel density estimation calculates the density of features in the neighbourhood around those features.

# %%
sns.distplot(df['total_bill'],kde=True, bins = 30)

#bins define smoothness or sharpness in your plot
# Out:
# <Axes: xlabel='total_bill', ylabel='Density'>

# %% [markdown]
# # jointplot
#
# match up two distplots for bivariate data. kind parameter: 'scatter', 'reg','kde','hex','resid'

# %%
sns.jointplot(x='total_bill',y='tip',data=df, kind='scatter')
plt.show()

# %%
sns.jointplot(x='total_bill',y='tip',data=df, kind='hex')
plt.show()

# %%
sns.jointplot(x='total_bill',y='tip',data=df, kind='reg')
plt.show()

# %%
sns.jointplot(x='total_bill',y='tip',data=df, kind='kde')
plt.show()

# %% [markdown]
# # Pairplot
#
# pairwise relationships across entire df (for numerical column, although it supports categorical columns through 'hue')

# %%
df.columns
# Out:
# Index(['total_bill', 'tip', 'sex', 'smoker', 'day', 'time', 'size',
#        'price_per_person', 'Payer Name', 'CC Number', 'Payment ID'],
#       dtype='object')

# %%
sns.pairplot(df[['total_bill', 'tip', 'size',
       'price_per_person']])

# %%
sns.pairplot(df, hue = 'day', palette="viridis")

# %% [markdown]
# # rugplot
#
# dash mark for every point on a univariate distribution. Building block of a KDE plot

# %%
sns.kdeplot(df['tip'])
sns.rugplot(df['tip'])
# Out:
# <Axes: xlabel='tip', ylabel='Density'>

# %%
sns.kdeplot(df['total_bill'])
sns.rugplot(df['total_bill'])
# Out:
# <Axes: xlabel='total_bill', ylabel='Density'>

# %% [markdown]
# # Categorical Data Plots
#
#
# ### Bar Plot and Count Plot

# %%
sns.barplot(x='day',y='tip',data=df, hue = 'sex', estimator=np.mean)
# Out:
# <Axes: xlabel='day', ylabel='tip'>

# %%
sns.countplot(data=df, x='smoker', saturation = 0.5, hue = 'day')
# Out:
# <Axes: xlabel='smoker', ylabel='count'>

# %% [markdown]
# ### Boxplot and Violinplot

# %%
sns.boxplot(y='smoker',x='total_bill',data=df,medianprops={"color": "white"},orient="h")
# Out:
# <Axes: xlabel='total_bill', ylabel='smoker'>

# %%
sns.violinplot(x='smoker',y='total_bill', data=df, hue='sex', split = True)
# Out:
# <Axes: xlabel='smoker', ylabel='total_bill'>

# %% [markdown]
# # Stripplot

# %%
sns.stripplot(x='day',y='total_bill',data=df)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
#swarmplot
sns.swarmplot(x='day',y='total_bill',data=df)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
df.columns
# Out:
# Index(['total_bill', 'tip', 'sex', 'smoker', 'day', 'time', 'size',
#        'price_per_person', 'Payer Name', 'CC Number', 'Payment ID'],
#       dtype='object')

# %%
df[['total_bill','tip','price_per_person']].corr()
#corr is extent to which two variables are linearly related
# Out:
#                   total_bill       tip  price_per_person
# total_bill          1.000000  0.675734          0.647554
# tip                 0.675734  1.000000          0.347405
# price_per_person    0.647554  0.347405          1.000000

# %%
sns.heatmap(df[['total_bill','tip','price_per_person']].corr(), annot=True)
# Out:
# <Axes: >
